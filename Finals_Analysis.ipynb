# %% [markdown]
# ##### Overall Analysis:
# ##### Note: Total scores are calcuated by combining difficulty scores (Diff) and exectution scores (Exec)
# * Oleg has the best posibility to get high Diff score, while Tomas and Robert have the lowest chances.
# * Garam has the best posibility to get high Exec score, while Kevin has the lowest chance.
# * Xiao has the best posibility to get high Total score, while Kevin has the lowest chance.

# %% [markdown]
# ### First step, import libraries.

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import datasets.
# ### As every athlete is an all-arounder, factoring specialists is not necessary and thus makes organization of athletes simple.
# ### Every athlete participate 6 different Apparatus/Events and have the following evaluations: Diff, Exec, Total and Rank

# %%
df = pd.read_csv("World_Champs_Men's_All-Around.csv")
df.head(12)
# Out:
#             Name  Overall Rank Nationality     Apparatus  Diff   Exec   Total  \
# 0   Xiao Ruoteng             1         CHN         Floor   5.9  8.533  14.433
# 1   Xiao Ruoteng             1         CHN  Pommel Horse   6.1  8.700  14.800
# 2   Xiao Ruoteng             1         CHN         Rings   5.7  8.100  13.800
# 3   Xiao Ruoteng             1         CHN         Vault   5.6  9.300  14.900
# 4   Xiao Ruoteng             1         CHN         PBars   6.0  8.600  14.600
# 5   Xiao Ruoteng             1         CHN      High Bar   6.0  8.400  14.400
# 6    Lin Chaopan             2         CHN         Floor   6.2  8.316  14.516
# 7    Lin Chaopan             2         CHN  Pommel Horse   5.8  8.466  14.266
# 8    Lin Chaopan             2         CHN         Rings   5.6  8.066  13.666
# 9    Lin Chaopan             2         CHN         Vault   5.6  9.300  14.900
# 10   Lin Chaopan             2         CHN         PBars   6.4  8.400  14.800
# 11   Lin Chaopan             2         CHN      High Bar   6.2  8.100  14.300
#
#     Rank
# 0      5
# 1      2
# 2     10
# 3      3
# 4      8
# 5      3
# 6      3
# 7      3
# 8     12
# 9      3
# 10     5
# 11     5

# %% [markdown]
# ### Below is the number of participating athlete(s) of each country
# ##### Analysis: CHN, LTU, RUS, SUI and TUR have 2 athletes while other countries have 1 athlete.

# %%
pd.DataFrame(df.groupby(['Nationality'])['Name'].count()/6).astype(int)
# Out:
#              Name
# Nationality
# ARM             1
# BRA             1
# CAN             1
# CHN             2
# COL             1
# CUB             1
# CYP             1
# GBR             1
# GER             1
# JPN             1
# KOR             1
# LTU             2
# MEX             1
# RUS             2
# SP              1
# SUI             2
# TUR             2
# UKR             1
# USA             1

# %% [markdown]
# ## Part 1: Analysis by Athlete
# ### Below, athletes are evaluated based on rank
# ##### Overall Analysis: Lin and Xiao perform extremely well while Kevin and Joel have seen better days.

# %%
sns.set_style('darkgrid', {'axis.facecolor':'black'})
vis1 = sns.boxplot(data=df, y='Name', x='Rank')

# %%
sns.set_style('darkgrid', {'axis.facecolor':'black'})
f, axes= plt.subplots(1, 3, figsize=(15,4))
ax = sns.boxplot(x='Name', y='Diff', data=df,ax = axes[0])
ax = ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
ax = sns.boxplot(x='Name', y='Exec', data=df,ax = axes[1])
ax = ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
ax = sns.boxplot(x='Name', y='Total', data=df,ax = axes[2])
ax = ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %% [markdown]
# ### Scores of specific Apparatus
# ##### Analysis:
# ##### Note: Apparatus actually have a pre-deteremine order (Literally called "Olympic Order"). The order listed below is the Olympic order for Men's Gymnastics.
# ##### Note 2: Pbars stands for Parallel Bar. High Bar is formally known as Horizonatal Bar but we will call this event as High Bar as this is what it is known as.
# * In Floor, Kenzo perform best, while Ferhat perform worst.
# * In Pommel Horse, David perform best, while Joel perform worst.
# * In Rings, Oleg perform best, while Tomas perform worst.
# * In Vault, Manrique perform best, while Philipp perform worst.
# * In PBars, David perform best, while Kevin perform worst.
# * In High Bar, Pablo perform best, while Nikita perform worst.

# %%
sns.set_style('darkgrid', {'axis.facecolor':'black'})
g = sns.FacetGrid(df, row="Apparatus", size=6)
g = g.map(sns.barplot, "Total", "Name",  palette="Blues_d")
g = g.map(sns.barplot, "Diff", "Name",  palette="Reds")
g = g.axes[5,0].set_xlabel('Toal score and Diff score')

# %% [markdown]
# ### Finally, let's compare the overall rank and rank of them
# ##### Analysis:
# Xiao, Lin and Kenzo perform poorly on Rings

# %%
sns.set_style('dark', {'axis.facecolor':'black'})
g = sns.FacetGrid(df, row="Apparatus", size=6)
kws= dict(s=6, linewidth=0.5, edgecolor='black')
g = g.map(sns.stripplot, "Rank", 'Name', color='Red', **kws)
g = g.map(sns.stripplot, "Overall Rank", 'Name',color='blue', **kws)
g = g.axes[5,0].set_xlabel('Overall Rank(Blue) and Rank(Red)')

# %% [markdown]
# ## Part 2: Analysis by Country
# ### Below, countries will be ranked by rank
# ##### Analysis: CHN  perform extremely well while SP perform poorly.

# %%
sns.set_style('darkgrid', {'axis.facecolor':'black'})
vis1 = sns.boxplot(data=df, y='Nationality', x='Rank')

# %% [markdown]
# ### Now, let's look at exact scores
# ##### Analysis:
# * UKR has the best posibility to get high Diff score, while LTU have the lowest chances.
# * KOR has the best posibility to get high Exec score, while MEX has the lowest chance.
# * CHN and RUS has the best posibility to get high Total score, while MEX has the lowest chance.

# %%
sns.set_style('darkgrid', {'axis.facecolor':'black'})
f, axes= plt.subplots(1, 3, figsize=(15,4))
ax = sns.boxplot(x='Nationality', y='Diff', data=df,ax = axes[0])
ax = ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
ax = sns.boxplot(x='Nationality', y='Exec', data=df,ax = axes[1])
ax = ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
ax = sns.boxplot(x='Nationality', y='Total', data=df,ax = axes[2])
ax = ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %% [markdown]
# ### Now, let's check the score of specific Apparatus
# ##### Analysis:
# * Floor: JPN perform best, while CYP perform worst.
# * Pommel Horse: CHN perform best, while SP perform worst.
# * Rings: UKR perform best, while LTU perform worst.
# * Vault: PN perform best, while GER perform worst.
# * PBars: UKR perform best, while MEX perform worst.
# * High Bar: GBR perform best, while SP perform worst.

# %%
sns.set_style('darkgrid', {'axis.facecolor':'black'})
g = sns.FacetGrid(df, row="Apparatus", size=6)
g = g.map(sns.barplot, "Total", "Nationality",  palette="Blues_d")
g = g.map(sns.barplot, "Diff", "Nationality",  palette="Reds")
g = g.axes[5,0].set_xlabel('Toal score and Diff score')

# %% [markdown]
# ### Note: I take no credit with this dataset. Majority of this has been found through Kaggle and I simply adjusted some of the code for analysis.
